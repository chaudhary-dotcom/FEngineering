# %% [markdown]
# # Feature Engeneering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('world university Ranking.csv')

# %%
df.sample(5)
# Out:
#            Rank                            University   Location  \
# 1596      1501+                     Jember University  Indonesia
# 1815      1501+  Universidade Nove de Julho (Uninove)     Brazil
# 2444   Reporter     Saint Thomas University, Colombia   Colombia
# 1241  1201–1500                   Lorestan University       Iran
# 345     301–350                  University of Trento      Italy
#
#      Overall Score  Overall Teaching Score  Research Score  Research Quality  \
# 1596     10.5–25.1                    10.7             9.4              17.7
# 1815     10.5–25.1                    17.9             8.4              10.7
# 2444           NaN                     NaN             NaN               NaN
# 1241     25.2–30.6                    27.8            11.7              47.0
# 345      51.1–53.6                    33.7            35.1              78.9
#
#       Industry Income Score  International Outlook Score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3243 entries, 0 to 3242
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         3243 non-null   object
#  1   University                   3243 non-null   object
#  2   Location                     3243 non-null   object
#  3   Overall Score                2510 non-null   object
#  4   Overall Teaching Score       2510 non-null   float64
#  5   Research Score               2510 non-null   float64
#  6   Research Quality             2510 non-null   float64
#  7   Industry Income Score        2510 non-null   float64
#  8   International Outlook Score  2510 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 228.1+ KB

# %%
df.isnull().sum()
# Out:
# Rank                             0
# University                       0
# Location                         0
# Overall Score                  733
# Overall Teaching Score         733
# Research Score                 733
# Research Quality               733
# Industry Income Score          733
# International Outlook Score    733
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                           0
# University                     0
# Location                       0
# Overall Score                  0
# Overall Teaching Score         0
# Research Score                 0
# Research Quality               0
# Industry Income Score          0
# International Outlook Score    0
# dtype: int64

# %%
df.shape
# Out:
# (2510, 9)

# %%
df[df['Location'] == 'Nepal']
# Out:
#        Rank            University Location Overall Score  \
# 1607  1501+  Kathmandu University    Nepal     10.5–25.1
# 1781  1501+  Tribhuvan University    Nepal     10.5–25.1
#
#       Overall Teaching Score  Research Score  Research Quality  \
# 1607                    11.3            10.9              29.4
# 1781                    10.8             8.0              48.6
#
#       Industry Income Score  International Outlook Score
# 1607                   16.6                         56.5
# 1781                   17.5                         46.7

# %%
df.head()
# Out:
#   Rank                             University        Location Overall Score  \
# 0    1                   University of Oxford  United Kingdom          98.5
# 1    2  Massachusetts Institute of Technology   United States          98.1
# 2    3                     Harvard University   United States          97.7
# 3    4                   Princeton University   United States          97.5
# 4    5                University of Cambridge  United Kingdom          97.4
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    97.3            99.9              99.3
# 3                    98.3            98.0              98.9
# 4                    95.9            99.9              97.6
#
#    Industry Income Score  International Outlook Score
# 0                   99.6                         97.3
# ...

# %%
df['Overall Score2'] = (df['Overall Teaching Score'] + df['Research Score'] + df['Research Quality'] + df['Industry Income Score'] + df['International Outlook Score'])/5
df.head()
# Out:
#   Rank                             University        Location Overall Score  \
# 0    1                   University of Oxford  United Kingdom          98.5
# 1    2  Massachusetts Institute of Technology   United States          98.1
# 2    3                     Harvard University   United States          97.7
# 3    4                   Princeton University   United States          97.5
# 4    5                University of Cambridge  United Kingdom          97.4
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    97.3            99.9              99.3
# 3                    98.3            98.0              98.9
# 4                    95.9            99.9              97.6
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# ...

# %%
df.drop(columns=['Rank'], inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(525)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#                               University        Location Overall Score  \
# 0                   University of Oxford  United Kingdom          98.5
# 1  Massachusetts Institute of Technology   United States          98.1
# 2                     Harvard University   United States          97.7
# 3                   Princeton University   United States          97.5
# 4                University of Cambridge  United Kingdom          97.4
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    97.3            99.9              99.3
# 3                    98.3            98.0              98.9
# 4                    95.9            99.9              97.6
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# ...

# %%
df.sort_values("Overall Score2", ascending=False, inplace=True)

# %%
df.head()
# Out:
#                               University        Location Overall Score  \
# 0                   University of Oxford  United Kingdom          98.5
# 1  Massachusetts Institute of Technology   United States          98.1
# 6     California Institute of Technology   United States          96.3
# 5                    Stanford University   United States          97.2
# 3                   Princeton University   United States          97.5
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 6                    95.2            97.5              97.3
# 5                    97.5            97.3              99.6
# 3                    98.3            98.0              98.9
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# ...

# %%
df.drop(columns=['Overall Score'], inplace=True)

# %%
df.head()
# Out:
#                               University        Location  \
# 0                   University of Oxford  United Kingdom
# 1  Massachusetts Institute of Technology   United States
# 6     California Institute of Technology   United States
# 5                    Stanford University   United States
# 3                   Princeton University   United States
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 6                    95.2            97.5              97.3
# 5                    97.5            97.3              99.6
# 3                    98.3            98.0              98.9
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# 1                  100.0                         93.8           97.74
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index                             University        Location  \
# 0      0                   University of Oxford  United Kingdom
# 1      1  Massachusetts Institute of Technology   United States
# 2      6     California Institute of Technology   United States
# 3      5                    Stanford University   United States
# 4      3                   Princeton University   United States
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    95.2            97.5              97.3
# 3                    97.5            97.3              99.6
# 4                    98.3            98.0              98.9
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# 1                  100.0                         93.8           97.74
# ...

# %%
df.drop(columns='index', inplace=True)

# %%
df.head()
# Out:
#                               University        Location  \
# 0                   University of Oxford  United Kingdom
# 1  Massachusetts Institute of Technology   United States
# 2     California Institute of Technology   United States
# 3                    Stanford University   United States
# 4                   Princeton University   United States
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    95.2            97.5              97.3
# 3                    97.5            97.3              99.6
# 4                    98.3            98.0              98.9
#
#    Industry Income Score  International Outlook Score  Overall Score2
# 0                   99.6                         97.3           98.50
# 1                  100.0                         93.8           97.74
# ...

# %%
df['Rank'] = df.index + 1

# %%
df.rename(columns={'Overall Score2': 'Overall Score'}, inplace=True)

# %%
df.head()
# Out:
#                               University        Location  \
# 0                   University of Oxford  United Kingdom
# 1  Massachusetts Institute of Technology   United States
# 2     California Institute of Technology   United States
# 3                    Stanford University   United States
# 4                   Princeton University   United States
#
#    Overall Teaching Score  Research Score  Research Quality  \
# 0                    96.8           100.0              98.8
# 1                    99.2            96.0              99.7
# 2                    95.2            97.5              97.3
# 3                    97.5            97.3              99.6
# 4                    98.3            98.0              98.9
#
#    Industry Income Score  International Outlook Score  Overall Score  Rank
# 0                   99.6                         97.3          98.50     1
# 1                  100.0                         93.8          97.74     2
# ...

# %%
df.to_csv('university_rank_clean_data.csv', index=False)

# %%
clean_df = pd.read_csv('university_rank_clean_data.csv')

# %%
clean_df.sample(5)
# Out:
#                                     University Location  \
# 1733             Bharati Vidyapeeth University    India
# 1410  Maharishi Markandeshwar University (MMU)    India
# 613         Ben-Gurion University of the Negev   Israel
# 1521              University of Nigeria Nsukka  Nigeria
# 1784              Université 8 Mai 1945 Guelma  Algeria
#
#       Overall Teaching Score  Research Score  Research Quality  \
# 1733                    25.9            10.2              22.2
# 1410                    27.1            10.0              56.5
# 613                     35.8            31.7              59.9
# 1521                    29.4            10.4              36.7
# 1784                    17.0             8.6              28.4
#
#       Industry Income Score  International Outlook Score  Overall Score  Rank
# 1733                   34.9                         19.3          22.50  1734
# 1410                   18.4                         32.6          28.92  1411
# ...

# %%
df.columns
# Out:
# Index(['University', 'Location', 'Overall Teaching Score', 'Research Score',
#        'Research Quality', 'Industry Income Score',
#        'International Outlook Score', 'Overall Score', 'Rank'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1985 entries, 0 to 1984
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   University                   1985 non-null   object
#  1   Location                     1985 non-null   object
#  2   Overall Teaching Score       1985 non-null   float64
#  3   Research Score               1985 non-null   float64
#  4   Research Quality             1985 non-null   float64
#  5   Industry Income Score        1985 non-null   float64
#  6   International Outlook Score  1985 non-null   float64
#  7   Overall Score                1985 non-null   float64
#  8   Rank                         1985 non-null   int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 139.7+ KB
